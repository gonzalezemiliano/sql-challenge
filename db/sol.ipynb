# %% [markdown]
# # Challenge Tecnico de SQL
#
# **Objetivos:**
#
# * Realizar consultas en SQL, interactuando con una base de datos alojada en un servidor de base de datos PostgreSQL.
#
# En este challenge vamos a partir de una base de datos de películas con datos [obtenidos del sitio IMDB]()
#
# **Entrega:** Realizar todas las actividades que se describen en este notebook. Si es necesario, se pueden agregar más celdas tanto de tipo markdown como código. Entregar el notebook modificado que refleje el trabajo realizado por el grupo, incluyendo respuestas, explicaciones y el código generado.

# %% [markdown]
# # 3. Conexión a la base de datos desde el notebook

# %% [markdown]
# Independientemente de que instancia usemos, vamos a utilizar la biblioteca [ipython-sql](https://pypi.org/project/ipython-sql/) para ejecutar comandos en forma interactiva desde este notebook.
#
# La celda a continuación instala esta biblioteca

# %%
# !pip3 install ipykernel
# !pip3 install ipython-sql
# !pip3 install psycopg2

# %% [markdown]
#  y luego cargamos el módulo

# %%
# %load_ext sql

# Fix for prettytable style issue with modern approach
import prettytable
if 'DEFAULT' not in prettytable.__dict__:
    from prettytable import TableStyle
    prettytable.DEFAULT = TableStyle.DEFAULT

# %config SqlMagic.style = 'DEFAULT'

# %% [markdown]
# Si estamos usando un servidor local usamos estre string de conexión, reemplazando PASS por la contraseña que hayan elegido para el usuario portgres al momento de la instalación

# %%
#conexion local

# %sql postgresql://emilianogonzalez@localhost/imdb

# %% [markdown]
# En cualquiera de los dos casos, luego hacemos esta consulta de prueba

# %%
# %sql SELECT * FROM movies LIMIT 10

# %% [markdown]
# # 4. Consultas a resolver
#
# A continuación se plantean las consultas a resolver. Para cada una de ellas proveer una solución en lenguaje SQL. Para las consultas en SQL **no se podrán utilizar** subconsultas en el FROM, vistas, ni la cláusula WITH
#
# En algunos casos se solicitará además discutir si es posible o no solucionar esa consulta en Álgebra Relacional o Cálculo Relacional, y de ser posible se deberá proveer una solución en el lenguaje indicado en cada caso.

# %% [markdown]
# ## Consulta 1
#
# Devolver el nombre y apellido de aquellas personas para las cuales no se tiene registrada fecha de fallecimiento.
# Ordenar los resultados por nombre en forma ascendente, y devolver sólo los primeros 10 resultados.

# %%
# %%sql
# select p.name
# from people p
# where p.birthdate isnull
# order by p.name limit 10;
# Out:
#  * postgresql://bdatos24:***@localhost:25432
# 10 rows affected.
# [('Aaron Au',),
#  ('Aaron Berg',),
#  ('Aaron Brumfield',),
#  ('Aaron D. Spears',),
#  ('Aaron Fors',),
#  ('Aaron Hendry',),
#  ('Aaron Hitz',),
#  ("Aaron ''Ike'' Stielstra",),
#  ('Aaron Izbicki',),
#  ('Aaron Joseph',)]

# %% [markdown]
# ## Consulta 2
#
# Devolver el total de películas estrenadas en 2012 y el promedio de sus presupuestos. El resultado debe tener dos columnas: una llamada `total_2012` y otra `promedio_2012`.

# %%
# %%sql
# select count(*) as "total_2012",avg(budget) as "promedio_2012"
# from movies m
# where "date" >= '2012-01-01' and "date" < '2013-01-01';
# Out:
#  * postgresql://bdatos24:***@localhost:25432
# 1 rows affected.
# [(49, Decimal('69828081.632653061224'))]

# %% [markdown]
# ¿es posible resolver esta consulta en Álgebra Relacional? De serlo, proveea una solución y de lo contrario explique por qué no es posible.

# %% [markdown]
# ### Solución en Álgebra relacional a la consulta 2
# No se puede hacer en algebra relacional ya que no se puede sacar promedio, no se pueden calcular totales.

# %% [markdown]
# ## Consulta 3
#
# Para cada saga, devolver su nombre y la cantidad de películas que la componen. Ordenar los resultados por cantidad de películas en forma descendiente.

# %%
# %%sql
# select s.name as "Nombre de la Saga", count (mis.movie_id) as "Cantidad de peliculas"
# from movie_in_saga mis right outer join sagas s on s.id = saga_id
# group by s.name,saga_id
# order by "Cantidad de peliculas" desc ;
# Out:
#  * postgresql://bdatos24:***@localhost:25432
# 216 rows affected.
# [('Star Wars', 11),
#  ('James Bond - 007', 9),
#  ('The Fast and the Furious', 7),
#  ('Shrek', 5),
#  ('Jurassic Park', 5),
#  ('Alien', 5),
#  ('Terminator', 5),
#  ('Pirates of the Caribbean', 4),
#  ('Resident Evil', 4),
#  ('Underworld', 4),
#  ('Predator', 3),
#  ('Toy Story', 3),
#  ('The Dark Knight Trilogy', 3),
#  ('RoboCop', 3),
#  ('Indiana Jones', 3),
#  ('Transformers', 3),
#  ('Back to the Future', 3),
#  ('Blade', 3),
#  ('The Hobbit', 3),
#  ('The Punisher', 2),
#  ('Meet the Parents', 2),
#  ('Mad Max', 2),
#  ('Beverly Hills Cop Serie', 2),
#  ('Asterix', 2),
#  ('Annabelle', 2),
#  ('Conan', 2),
#  ('Cube Movie Series', 2),
#  ('Speed', 2),
#  ('Hellraiser', 2),
#  ('Tomb Raider', 2),
#  ('The Matrix', 2),
#  ('Stargate Franchise', 2),
#  ('Finding Nemo', 2),
#  ('Jaws', 2),
#  ('Mission: Impossible', 2),
#  ('Crank', 2),
#  ('Shaft Movie Series', 2),
#  ('John Wick', 2),
#  ('The Powerpuff Girls', 1),
#  ("The Emperor's New Groove", 1),
#  ('Highlander', 1),
#  ('Monsters, Inc.', 1),
#  ('Space Jam', 1),
#  ('The Twilight Saga', 1),
#  ('Dr. Dolittle', 1),
#  ('Scary Movie', 1),
#  ('The Simpsons', 1),
#  ('Sin City', 1),
#  ('Dune', 1),
#  ('American Ninja', 1),
#  ('The X Files', 1),
#  ('The Butterfly Effect', 1),
#  ('Starship Troopers', 1),
#  ('Bring It On', 1),
#  ('Garfield', 1),
#  ('Wolverine', 1),
#  ('xXx', 1),
#  ('The Arrival', 1),
#  ('Beethoven', 1),
#  ('Ted', 1),
#  ('Karate Kid', 1),
#  ('Insidious', 1),
#  ('Halloween', 1),
#  ('French Connection', 1),
#  ('Wrong Turn', 1),
#  ('Ghostbusters', 1),
#  ('A Nightmare on Elm Street', 1),
#  ('The Divergent Series', 1),
#  ('The Nightmare Before Christmas', 1),
#  ('AVP: Alien vs. Predator', 1),
#  ('The Lion King', 1),
#  ('Soukromé století', 0),
#  ('Schafft Wissen Schaft Wissen', 0),
#  ('Meatballs', 0),
#  ('The Distraction Dilemma', 0),
#  ('Saw', 0),
#  ('In Wahrheit', 0),
#  ('Woche der Gesundheit', 0),
#  ('Casper', 0),
#  ('Fred Vargas', 0),
#  ('Vampire Hunter D', 0),
#  ('Lotta & ...', 0),
#  ('Sturm aus dem Norden', 0),
#  ('Spyro', 0),
#  ('Osmosis Jones', 0),
#  ('K-9', 0),
#  ('Landkrimi', 0),
#  ('The Chronicles of Narnia', 0),
#  ('Das Finale', 0),
#  ('Yusuf Trilogie', 0),
#  ('Иван Грозный', 0),
#  ('Der Doc und die Hexe', 0),
#  ('Olympia', 0),
#  ('Smetto quando voglio', 0),
#  ('Neben der Spur', 0),
#  ('Emotionale Intelligenz', 0),
#  ('Northpole', 0),
#  ('The Last Reformation', 0),
#  ('Unser Körper', 0),
#  ('Marie Brand', 0),
#  ('Sprechstunde mit dem eigenen Ich', 0),
#  ('Paradise Lost', 0),
#  ('Usedom-Krimi', 0),
#  ('Die Lümmel von der ersten Bank', 0),
#  ('Werner', 0),
#  ('An American Tail', 0),
#  ('Walking Tall', 0),
#  ('Health Expo 2018', 0),
#  ('Die Rache des Homunculus', 0),
#  ('SOKO', 0),
#  ('Mass Effect', 0),
#  ('Angetrieben', 0),
#  ('Discworld', 0),
#  ('Re-Education', 0),
#  ('The Hollow Crown', 0),
#  ('Engel: Gute Geister zwischen Himmel und Erde', 0),
#  ("God's Not Dead", 0),
#  ('Final Fantasy', 0),
#  ('Die Deutschen', 0),
#  ('The Hills Have Eyes', 0),
#  ('Wir werden alle überwacht!', 0),
#  ("L'ennemi movies1 n°1", 0),
#  ('Cocaine Cowboys', 0),
#  ('Teenage Mutant Ninja Turtles', 0),
#  ('Apur Sansar', 0),
#  ('Molly Hartley', 0),
#  ('Unzensiert: Was die Massenmedien Ihnen verschweigen!', 0),
#  ('Allmen', 0),
#  ('Mortal Kombat', 0),
#  ('Zeitgeschehen', 0),
#  ('Zukunft Erde', 0),
#  ('One Piece', 0),
#  ('Bludenz 2007', 0),
#  ('Games Odyssey', 0),
#  ('Willy Wuff', 0),
#  ('The Art of War', 0),
#  ('Sly Cooper', 0),
#  ('Drums of Fu Manchu', 0),
#  ('Amityville', 0),
#  ('Die Drei ???', 0),
#  ('ヱヴァンゲリヲン新劇場版', 0),
#  ('Zukunftsvisionen', 0),
#  ('The Legend of Spyro', 0),
#  ('Riget', 0),
#  ('Kreation versus Evolution', 0),
#  ('人間の條件', 0),
#  ('Goal', 0),
#  ('Dreileben', 0),
#  ('Fantozzi', 0),
#  ('Offenbarung: Gottes "roadmap" zum ewigen Frieden', 0),
#  ('Grindhouse', 0),
#  ('The NeverEnding Story', 0),
#  ('The Net', 0),
#  ('Silent Hill', 0),
#  ('Die 5 grossen Reformatoren', 0),
#  ('Mike Hammer', 0),
#  ('Reformation', 0),
#  ('Homunculus', 0),
#  ('Ware Tier', 0),
#  ('Kommissar X', 0),
#  ('Was kann ich glauben? - Von Konfessionen und Religionen', 0),
#  ('I Kina spiser de hunde', 0),
#  ('Der Bockerer', 0),
#  ('Dekalog', 0),
#  ('Fack ju Göhte', 0),
#  ('Blondie', 0),
#  ('Die Heilerin', 0),
#  ('Zärtliche Chaoten', 0),
#  ('Rupan sansei', 0),
#  ('The Whole Yards', 0),
#  ('The Joy of ...', 0),
#  ('Shark Tale', 0),
#  ('Natürlich heilen und pflegen', 0),
#  ('Polt', 0),
#  ('Keine Zeit für Rebellion', 0),
#  ('Die Toten von Salzburg', 0),
#  ('Gesundheit: kein Zufall!', 0),
#  ('Edgar Wallace', 0),
#  ('Uncharted', 0),
#  ('Vi på Saltkråkan', 0),
#  ('Konflikt und Triumph', 0),
#  ('Zeichen der Zeit', 0),
#  ('Winnetou', 0),
#  ('Halo', 0),
#  ('Drogues et cerveau', 0),
#  ('Die Hebamme', 0),
#  ('Hart to Hart', 0),
#  ('デスノート', 0),
#  ('Niederbayernkrimi', 0),
#  ('500 Jahre Reformation', 0),
#  ('Kluftingerkrimi', 0),
#  ('Halloweentown', 0),
#  ('Fantômas-Trilogie', 0),
#  ('Dengler', 0),
#  ('Krebs - Kampf der Zellen', 0),
#  ('Reihenhaus', 0),
#  ('Harold & Kumar', 0),
#  ('Lost Boys', 0),
#  ('Taxi', 0),
#  ('Die Jagd nach ...', 0),
#  ('攻殻機動隊', 0),
#  ('Les Bronzés', 0),
#  ("The Cousins' War", 0),
#  ('Guardians of the Galaxy', 0),
#  ('Mitten in Deutschland: NSU', 0),
#  ('Zwei Väter einer Tochter', 0),
#  ('Der Mann ohne Namen', 0),
#  ('Blind ermittelt', 0),
#  ('Kottan ermittelt', 0),
#  ('Die Neue Weltordnung', 0),
#  ('Winnetou - Der Mythos lebt', 0),
#  ('Kreation - Evolution', 0),
#  ('Nativity', 0),
#  ('Fantômas', 0),
#  ('Lammbock', 0),
#  ('Macht der Gedanken', 0)]

# %% [markdown]
# ¿es posible resolver esta consulta en Cálculo Relacional? De serlo, proveea una solución y de lo contrario explique por qué no es posible.

# %% [markdown]
# ### Solución en Cálculo relacional a la consulta 3
#
# No se puede hacer en Calculo relacional ya que no se puede contar elementos , no se pueden calcular totales.

# %% [markdown]
# ## Consulta 4
#
# Devolver parejas nombre de película, nombre de persona, tal que esa persona es la única que forma parte del cast de esa película. Dicho de otra manera, para aquellas películas donde una sola persona realiza todos los trabajos, devolver el nombre de la película y el nombre de la persona.

# %%
# %%sql
# select m.name, p.name
# from movies m join casts c
#   on m.id = c.movie_id
#   join people p
#   on p.id = c.person_id
# where m.id in
# (
#   select c1.movie_id
#   from casts c1
#   group by c1.movie_id
#   having count(c1.person_id) = 1
# );
# Out:
#  * postgresql://bdatos24:***@localhost:25432
# 4 rows affected.
# [('Vuelve', 'Iván Noel'),
#  ('Megacities - Life in Loops', 'Wolfgang Thaler'),
#  ('The Crazies', 'George A. Romero'),
#  ('R100', 'Hitoshi Matsumoto')]

# %% [markdown]
# ¿es posible resolver esta consulta en Álgebra Relacional? De serlo, proveea una solución y de lo contrario explique por qué no es posible.

# %% [markdown]
# ### Solución en Álgebra relacional a la consulta 4
#
# $Casts(\underline{movie\_id},\underline{person\_id}, \underline{job\_id},\underline{role})$
# $Movies(\underline{id}, name, date, runtime, budget, revenue, homepage, vote\_average)$
# $People(\underline{id}, name, birthdate, deathdate, gender)  $
#
# $A = \Pi_{(\$1, \$2, \$6)} (Casts \Join_{ \space (\$1=\$5)} Movies)$
#
# $A(\underline{movie\_id}, \underline{person\_id}, name)$
#
# $B = (A - (A \Join_{ \space (\$2 \neq \$5 \space \land \space \$1 = \$4)} A))$
#
# $Sol = \Pi_{(\$3, \$5)} (\rho_{(person\_id -> id, \space name -> movie\_name)} \space (B) * People)$

# %% [markdown]
# ## Consulta 5
# Para cada saga, actores que participaron en todas sus películas. Devolver parejas id de saga, id de persona.

# %%
# %%sql
# select distinct mis.saga_id , c.person_id
# from casts c natural join movie_in_saga mis
# where (c.job_id = 4 or c.job_id = 15) and
# not exists
#     (select * from movie_in_saga mis2
#     where mis2.saga_id = mis.saga_id
#     and mis2.movie_id <> mis.movie_id
#     and not exists
#             (select * from casts c2
#             where c2.movie_id = mis2.movie_id and
#             (c2.job_id = 4 or c2.job_id = 15) and
#             c2.person_id = c.person_id));
# Out:
#  * postgresql://bdatos24:***@localhost:25432
# 673 rows affected.
# [(84, 3),
#  (84, 10942),
#  (188, 62),
#  (188, 109),
#  (188, 147),
#  (188, 328),
#  (188, 585),
#  (188, 888),
#  (188, 1121),
#  (188, 2139),
#  (188, 2295),
#  (188, 2296),
#  (188, 2297),
#  (188, 2299),
#  (188, 2478),
#  (188, 3133),
#  (188, 5915),
#  (188, 5916),
#  (188, 6278),
#  (188, 6279),
#  (188, 6280),
#  (188, 6407),
#  (188, 6408),
#  (188, 8693),
#  (188, 17039),
#  (188, 17832),
#  (188, 18070),
#  (188, 20496),
#  (188, 23285),
#  (188, 59456),
#  (188, 61847),
#  (188, 83663),
#  (188, 86647),
#  (188, 100565),
#  (188, 124238),
#  (188, 137184),
#  (188, 162104),
#  (188, 162759),
#  (188, 169312),
#  (188, 182665),
#  (188, 186295),
#  (188, 228957),
#  (264, 521),
#  (264, 1062),
#  (264, 1063),
#  (264, 1065),
#  (264, 1072),
#  (264, 11673),
#  (295, 85),
#  (295, 118),
#  (295, 2449),
#  (305, 776),
#  (305, 777),
#  (305, 787),
#  (305, 4689),
#  (495, 6487),
#  (528, 1100),
#  (735, 10814),
#  (735, 10823),
#  (1606, 500),
#  (1606, 10182),
#  (2326, 3967),
#  (2344, 530),
#  (2344, 1331),
#  (2344, 2192),
#  (2344, 2516),
#  (2344, 2975),
#  (2344, 6195),
#  (2344, 6384),
#  (2344, 8771),
#  (2344, 9443),
#  (2344, 9464),
#  (2344, 9575),
#  (2344, 9576),
#  (2344, 18286),
#  (2344, 33449),
#  (2344, 41784),
#  (2344, 52908),
#  (2344, 56347),
#  (2344, 62486),
#  (2344, 73883),
#  (2344, 91545),
#  (2344, 93163),
#  (2344, 95827),
#  (2344, 104895),
#  (2344, 117819),
#  (2344, 143283),
#  (2344, 164849),
#  (2344, 223615),
#  (2366, 6355),
#  (2366, 8607),
#  (2366, 8608),
#  (2366, 8609),
#  (2396, 16927),
#  (2980, 707),
#  (2980, 1524),
#  (2980, 1532),
#  (2980, 7672),
#  (2980, 7676),
#  (2980, 8542),
#  (2980, 8872),
#  (2980, 8873),
#  (2980, 8874),
#  (2980, 8875),
#  (2980, 10205),
#  (2980, 17396),
#  (2980, 17488),
#  (2980, 42545),
#  (2980, 44127),
#  (2980, 55930),
#  (2980, 60205),
#  (2980, 65924),
#  (2980, 68670),
#  (2980, 104498),
#  (2980, 105138),
#  (2980, 115151),
#  (2980, 134018),
#  (2980, 134904),
#  (87640, 17181),
#  (87640, 59117),
#  (87640, 73417),
#  (87640, 121667),
#  (87640, 150503),
#  (87640, 162741),
#  (87640, 171381),
#  (87640, 202515),
#  (89463, 10133),
#  (89463, 21259),
#  (89463, 55271),
#  (89463, 72541),
#  (89463, 72542),
#  (89463, 101622),
#  (93103, 204),
#  (93103, 327),
#  (93103, 3417),
#  (93103, 15852),
#  (93103, 21045),
#  (93103, 37153),
#  (93103, 56614),
#  (93103, 88794),
#  (93103, 106679),
#  (93103, 117902),
#  (93103, 118820),
#  (93103, 122692),
#  (93103, 166106),
#  (93103, 186961),
#  (93103, 189001),
#  (93103, 207057),
#  (93103, 223849),
#  (93103, 225572),
#  (93103, 229387),
#  (93103, 234562),
#  (93103, 236611),
#  (104293, 1737),
#  (104293, 5723),
#  (104293, 6384),
#  (104293, 6972),
#  (104293, 18354),
#  (104293, 54680),
#  (104293, 238678),
#  (109755, 1771),
#  (109755, 2387),
#  (109755, 4139),
#  (109755, 6942),
#  (109755, 9657),
#  (109755, 10859),
#  (109755, 13240),
#  (109755, 17041),
#  (109755, 17200),
#  (109755, 18973),
#  (109755, 20472),
#  (109755, 24357),
#  (109755, 33321),
#  (109755, 54194),
#  (109755, 55463),
#  (109755, 59841),
#  (109755, 60286),
#  (109755, 82849),
#  (109755, 94999),
#  (109755, 102946),
#  (109755, 140373),
#  (109755, 226796),
#  (111713, 1990),
#  (111713, 73417),
#  (111713, 94311),
#  (111713, 102081),
#  (111713, 190120),
#  (157876, 1532),
#  (157876, 4201),
#  (157876, 4604),
#  (157876, 23678),
#  (157876, 23681),
#  (157876, 23682),
#  (158314, 2387),
#  (158314, 6968),
#  (158314, 9452),
#  (158314, 17041),
#  (158314, 20766),
#  (158314, 21215),
#  (158314, 23628),
#  (158314, 35546),
#  (158314, 39189),
#  (158314, 42200),
#  (158314, 51551),
#  (158314, 52904),
#  (158314, 54589),
#  (158314, 65421),
#  (158314, 83371),
#  (158314, 95770),
#  (158314, 98257),
#  (158314, 111032),
#  (158314, 117185),
#  (158314, 119494),
#  (158314, 127305),
#  (158314, 160774),
#  (158314, 186106),
#  (158314, 207862),
#  (158314, 221861),
#  (158314, 223121),
#  (158314, 230050),
#  (158314, 230829),
#  (158314, 230929),
#  (158314, 231022),
#  (158314, 231573),
#  (158314, 233401),
#  (158314, 234205),
#  (158314, 237239),
#  (158314, 248161),
#  (158314, 248208),
#  (158314, 250432),
#  (158314, 251956),
#  (158314, 252441),
#  (158314, 252442),
#  (158459, 64),
#  (158459, 192),
#  (158459, 2037),
#  (158459, 3894),
#  (158459, 3895)]

# %% [markdown]
# ¿es posible resolver esta consulta en Cálculo Relacional? De serlo, proveea una solución y de lo contrario explique por qué no es posible.

# %% [markdown]
# ### Solución en Cálculo relacional a la consulta 5
#
# $\{<s.saga\_id, c.person\_id> \space / \space movie\_in\_saga(s) \land \space casts(c) \land \space s.movie\_id = c.movie\_id \land \space$
# $(c.job\_id = 4 \lor \space c.job\_id = 15)\space \land$
# $(\lnot \exists m) (movie\_in\_saga( m ) \land m.saga\_id = s.saga\_id \land m.movie\_id \neq c.movie.id \space \land$
# $(\forall c2) ((cast(c2) \land c2.movie\_id = m.movie\_id \space \land \space (c2.job\_id = 4 \lor \space c2.job\_id = 15)) \to (c.person\_id \neq c2.person\_id)))\}$

# %% [markdown]
# ## Consulta 6
# Nombres de sagas que satisfacen que la fecha de la saga sea igual a la fecha de estreno de la película más reciente de la saga.

# %%
# %%sql
# select s.name
# from (sagas s join movie_in_saga mis  on s.id = mis.saga_id ) join movies m on m.id = mis.movie_id
# group by s.name,s.date
# having s.date = max(m.date);
# Out:
#  * postgresql://bdatos24:***@localhost:25432
# 21 rows affected.
# [('The Dark Knight Trilogy',),
#  ('Pirates of the Caribbean',),
#  ('xXx',),
#  ('Underworld',),
#  ('Karate Kid',),
#  ('Speed',),
#  ('Back to the Future',),
#  ('Star Wars',),
#  ('Wolverine',),
#  ('Tomb Raider',),
#  ('Crank',),
#  ('Predator',),
#  ('Cube Movie Series',),
#  ('Terminator',),
#  ('Toy Story',),
#  ('The Lion King',),
#  ('A Nightmare on Elm Street',),
#  ('Finding Nemo',),
#  ('Mad Max',),
#  ('Beverly Hills Cop Serie',),
#  ('The Hobbit',)]

# %% [markdown]
# ## Consulta 7
# Nombre y cantidad de películas de las sagas con las 5 mayores cantidades de películas. Ordenarlas por cantidad de películas en forma descendiente.

# %%
# %%sql
# select distinct s.name, count(mis.movie_id)
# from sagas s join movie_in_saga mis on s.id = mis.saga_id
# group by s.id
# having count(mis.movie_id) in
#     (select distinct count(mis3.movie_id)
#         from movie_in_saga mis3
#         group by mis3.saga_id
#         order by count(mis3.movie_id) desc
#         limit 5)
# order by count(mis.movie_id) desc;
# Out:
#  * postgresql://bdatos24:***@localhost:25432
# 10 rows affected.
# [('Star Wars', 11),
#  ('James Bond - 007', 9),
#  ('The Fast and the Furious', 7),
#  ('Alien', 5),
#  ('Jurassic Park', 5),
#  ('Shrek', 5),
#  ('Terminator', 5),
#  ('Pirates of the Caribbean', 4),
#  ('Resident Evil', 4),
#  ('Underworld', 4)]

# %% [markdown]
# ## Consulta 8
# Películas que sólo son referenciadas por películas con las que comparten al menos un género

# %%
# %%sql
# select  distinct mr.reference_to
# from (movie_references mr join movie_genres mg on mg.movie_id = mr.reference_to)
#     join movie_genres mg2 on mr.referenced_by = mg2.movie_id
# where mg.genre_id = mg2.genre_id;
# Out:
#  * postgresql://bdatos24:***@localhost:25432
# 17 rows affected.
# [(118,),
#  (479,),
#  (503,),
#  (806,),
#  (1272,),
#  (1636,),
#  (6575,),
#  (14555,),
#  (20289,),
#  (20713,),
#  (27872,),
#  (36279,),
#  (56448,),
#  (56824,),
#  (56837,),
#  (72461,),
#  (88451,)]

# %% [markdown]
# ¿es posible resolver esta consulta en Cálculo Relacional? De serlo, proveea una solución y de lo contrario explique por qué no es posible.

# %% [markdown]
# ### Solución en Cálculo relacional a la consulta 8
# $\{ < m.reference\_to> / \space movie\_references(m) \wedge \newline
# (\space (\exists g)(movie\_genres(g)\wedge g.movie\_id = m.reference\_to) \wedge \newline
# (\exists g2)(movie\_genres(g2)\wedge g2.movie\_id = m.referenced\_by) \wedge g.genre\_id = g2.genre\_id \space ) \}$
